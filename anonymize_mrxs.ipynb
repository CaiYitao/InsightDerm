# %%
from anonymize_slide import MrxsFile, anonymize_slide
import glob
import os

# %%
# using PythonCall
# MrxsFile = pyimport("anonomize_slide" => "MrxsFile")
dir = "/restricteddata/skincancer_kuk/Scanned_WSI/WSI/Derma_anonymized"
slides = sorted(glob.glob(os.path.join(dir,"**", "*.mrxs"), recursive=True))
print(slides)
# Out:
# ['/restricteddata/skincancer_kuk/Scanned_WSI/WSI/Derma_anonymized/20220921/slide-2022-09-20T12-17-43-R1-S1.mrxs', '/restricteddata/skincancer_kuk/Scanned_WSI/WSI/Derma_anonymized/20220921/slide-2022-09-20T12-49-30-R1-S2.mrxs', '/restricteddata/skincancer_kuk/Scanned_WSI/WSI/Derma_anonymized/20220921/slide-2022-09-20T13-23-27-R1-S3.mrxs', '/restricteddata/skincancer_kuk/Scanned_WSI/WSI/Derma_anonymized/20220921/slide-2022-09-20T13-32-33-R1-S4.mrxs', '/restricteddata/skincancer_kuk/Scanned_WSI/WSI/Derma_anonymized/20220921/slide-2022-09-20T13-51-50-R1-S5.mrxs', '/restricteddata/skincancer_kuk/Scanned_WSI/WSI/Derma_anonymized/20220921/slide-2022-09-20T14-26-50-R1-S6.mrxs', '/restricteddata/skincancer_kuk/Scanned_WSI/WSI/Derma_anonymized/20220921/slide-2022-09-20T14-30-11-R1-S7.mrxs', '/restricteddata/skincancer_kuk/Scanned_WSI/WSI/Derma_anonymized/20220921/slide-2022-09-20T14-35-45-R1-S8.mrxs', '/restricteddata/skincancer_kuk/Scanned_WSI/WSI/Derma_anonymized/20220921/slide-2022-09-20T14
# ...

# %%
for slide in slides:
    anonymize_slide(slide)
# Out:
# <function do_ventana_tif at 0x7f859e238430>
# <function do_aperio_svs at 0x7f859e238280>
# <function do_hamamatsu_ndpi at 0x7f859e238310>
# <function do_3dhistech_mrxs at 0x7f859e2383a0>
# <function do_ventana_tif at 0x7f859e238430>
# <function do_aperio_svs at 0x7f859e238280>
# <function do_hamamatsu_ndpi at 0x7f859e238310>
# <function do_3dhistech_mrxs at 0x7f859e2383a0>
# <function do_ventana_tif at 0x7f859e238430>
# <function do_aperio_svs at 0x7f859e238280>
# <function do_hamamatsu_ndpi at 0x7f859e238310>
# <function do_3dhistech_mrxs at 0x7f859e2383a0>
# <function do_ventana_tif at 0x7f859e238430>
# <function do_aperio_svs at 0x7f859e238280>
# <function do_hamamatsu_ndpi at 0x7f859e238310>
# <function do_3dhistech_mrxs at 0x7f859e2383a0>
# <function do_ventana_tif at 0x7f859e238430>
# <function do_aperio_svs at 0x7f859e238280>
# <function do_hamamatsu_ndpi at 0x7f859e238310>
# <function do_3dhistech_mrxs at 0x7f859e2383a0>
# <function do_ventana_tif at 0x7f859e238430>
# ...
